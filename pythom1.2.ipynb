# %% [markdown]
# ![TheBridge_logo_RGB_color.jpg](attachment:TheBridge_logo_RGB_color.jpg)

# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# ## EJERCICIOS PYTHON BASICO 3:
# ## Operaciones matemáticas, comparación y booleanas

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
#
# ## Ejercicio 1
# Tenemos las siguientes variables:
#
# ```Python
# A = 4
# B = "Text"
# C = 4.1
# ```
#
# Comprueba:
# 1. Si A y B son equivalentes
# 2. Si A y C NO son equivalentes
# 3. Si A es mayor que C
# 4. Si C es menor o igual que A
# 5. Si B NO es equivalente a C

# %% [markdown]
# Completa los siguiente ejercicios, la solución completa a los mismos se publicarán en el repo del curso a lo largo del sprint. En algunos ejercicios se muestra la solución final, para que puedas comprobar que lo has hecho bien, pero lo importante es el código que generes. ¡Vaaamos, a ello...!

# %%
A == B
A != B
A > C
C <= A
B != C
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-242198659.py in <cell line: 0>()
# ----> 1 A == B
#       2 A != B
#       3 A > C
#       4 C <= A
#       5 B != C
#
# NameError: name 'A' is not defined

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 2
# Crea un programa donde se recojan dos inputs del usuario, y el output del programa sea si esos inputs son iguales o no

# %%
edad = input("¿Qué edad tienes?: ")
altura = input("¿Cuánto mides?: ")
print(edad == altura)
# Out:
# ¿Qué edad tienes?: 27
# ¿Cuánto mides?: 1,75
# False

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 3
# Mismo programa que en 2, pero en esta ocasión tienen que ser tres inputs y dos salidas. Una de las salidas que nos indique si todos son iguales, y la otra si al menos dos inputs sí que lo son

# %%
edad = input("¿Qué edad tienes?: ")
altura = input("¿Cuánto mides?: ")
género = input("¿Qué género eres: ")
print("Coinciden todos los inputs", edad == altura == género)
print("Coinciden al menos dos inputs", edad == altura or edad == género or altura == género)
# Out:
# ¿Qué edad tienes?: 27
# ¿Cuánto mides?: 1.75
# ¿Qué género eres: masculino
# Coinciden todos los inputs False
# Coinciden al menos dos inputs False

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 4
# Razona sin ejecutar código el output que obtendremos de las siguientes sentencias
# 1. True and True and False
# 2. not ((True or False) and (True or False))
# 3. (False or False or False or True) and False
# 4. not False and True and not True

# %% [markdown]
# Me imagino que este ejercicio tiene que ver con las imágenes, no puedo ver desde Google Colab dichas fotos, también el formato de jupyter se ve distinto a los vídeos subidos en el Módulo 0. (Por ejemplo, yo no escojo la celda desde la izquierda, ni me salen las opciones como las de cambio entre code, markdown, aunque si me funcionen presionando "c" o "m")
# Aun así intentaré razonar los outputs:
# 1 False, el "and" implica que todas tegan que ser iguales, al haber un False, el resultado ha de ser False
# 2 False, al contener ambas la posibilidad de ser True or False, quiere decir que la condición de igualdad que implica el "and" es verdad, y cómo hay un not delante, not True implica que sea False
# 3 False, al comparar 3 "False" y 1 "True" con "or", el resultado ha de ser True, que no coincide con la condición del "and" final.
# 4 False, not False == a True, pero not True es False, asique no cumplen el "and"
